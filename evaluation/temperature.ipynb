# %% [markdown]
# # Effect of temperature

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Z-scores

# %%
# Load the data
data_path = 'z_scores.csv'
data = pd.read_csv(data_path)

# %%
# Filter the entries under "experiment" that start with "temperature-" followed by a number from 0 to 1
temperature_data = data[data['experiment'].str.match(r'temperature-[0-1]')]

# %%
# Extracting temperature values and converting them to floats for plotting
temperature_data['temperature'] = temperature_data['experiment'].str.replace('temperature-', '').astype(float)

# Plotting
plt.figure(figsize=(6, 4))
sns.lineplot(data=temperature_data, x='temperature', y='mean_z_score', hue='model', marker='o')
plt.title('Effect of Temperature on Z-Scores for Each Model')
plt.xlabel('Temperature')
plt.ylabel('Mean Z-Score')
plt.legend(title='Model') #, bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.savefig('temperature_z-score.pdf')

plt.show()
# Out:
# C:\Users\grandid\AppData\Local\Temp\1\ipykernel_6128\2404644040.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temperature_data['temperature'] = temperature_data['experiment'].str.replace('temperature-', '').astype(float)
# C:\Users\grandid\miniconda3\envs\llm_material_selection_jcise2\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\grandid\miniconda3\envs\llm_material_selection_jcise2\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\grandid\miniconda3\envs\llm_material_selection_jcise2\lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\grandid\miniconda3\envs\llm_material_selection_jcise2\lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\grandid\miniconda3\envs\llm_material_selection_jcise2\lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %% [markdown]
# ## Distance

# %%
distance_data_path = 'mean_distances.csv'
distance_data = pd.read_csv(distance_data_path)

# %%
# Filter the entries under "experiment" that start with "temperature-" followed by a number from 0 to 1
temperature_distance_data = distance_data[distance_data['experiment'].str.match(r'temperature-[0-1]')]

# Extracting temperature values and converting them to floats for plotting
temperature_distance_data['temperature'] = temperature_distance_data['experiment'].str.replace('temperature-', '').astype(float)
# Out:
# C:\Users\grandid\AppData\Local\Temp\1\ipykernel_6128\4232868035.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temperature_distance_data['temperature'] = temperature_distance_data['experiment'].str.replace('temperature-', '').astype(float)

# %%
# Plotting
plt.figure(figsize=(6, 4))
sns.lineplot(data=temperature_distance_data, x='temperature', y='mean_distances', hue='model', marker='o')
plt.title('Effect of Temperature on Z-Scores for Each Model')
plt.xlabel('Temperature')
plt.ylabel('Mean Z-Score')
plt.legend(title='Model') #, bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.savefig('temperature_distance.pdf')

plt.show()
# Out:
# C:\Users\grandid\miniconda3\envs\llm_material_selection_jcise2\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\grandid\miniconda3\envs\llm_material_selection_jcise2\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\grandid\miniconda3\envs\llm_material_selection_jcise2\lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\grandid\miniconda3\envs\llm_material_selection_jcise2\lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\grandid\miniconda3\envs\llm_material_selection_jcise2\lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
