# %% [markdown]
# # Effect of temperature

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Z-scores

# %%
# Load the data
data_path = 'z_scores.csv'
data = pd.read_csv(data_path)

# %%
# Filter the entries under "experiment" that start with "temperature-" followed by a number from 0 to 1
temperature_data = data[data['experiment'].str.match(r'temperature-[0-1]')]

# %%
# Load the full "Set3" ColorBrewer palette
full_palette = sns.color_palette("hls", n_colors=4)  # "Set3" has 12 distinct colors

# Select only the 2nd, 3rd, and 4th colors from the palette
selected_colors = full_palette[1:4]

# %%
sns.reset_defaults()
sns.set(font_scale=1.1)
sns.set_style('whitegrid')

# %%
# Extracting temperature values and converting them to floats for plotting
temperature_data['temperature'] = temperature_data['experiment'].str.replace('temperature-', '').astype(float)

# Plotting
plt.figure(figsize=(6, 4))
sns.lineplot(data=temperature_data, x='temperature', y='mean_z_score', hue='model', marker='o', palette=selected_colors)
plt.title('Effect of Temperature on Z-Scores for Each Model')
plt.xlabel('Temperature')
plt.ylabel('Mean z-score')
plt.legend(title='Model') #, bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.savefig('figures/temperature_z-score.pdf')

plt.show()
# Out:
# C:\Users\grandid\AppData\Local\Temp\1\ipykernel_48056\863448242.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temperature_data['temperature'] = temperature_data['experiment'].str.replace('temperature-', '').astype(float)

# %% [markdown]
# ## Distance

# %%
distance_data_path = 'mean_distances.csv'
distance_data = pd.read_csv(distance_data_path)

# %%
# Filter the entries under "experiment" that start with "temperature-" followed by a number from 0 to 1
temperature_distance_data = distance_data[distance_data['experiment'].str.match(r'temperature-[0-1]')]

# Extracting temperature values and converting them to floats for plotting
temperature_distance_data['temperature'] = temperature_distance_data['experiment'].str.replace('temperature-', '').astype(float)
# Out:
# C:\Users\grandid\AppData\Local\Temp\1\ipykernel_48056\4232868035.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temperature_distance_data['temperature'] = temperature_distance_data['experiment'].str.replace('temperature-', '').astype(float)

# %%
# Plotting
plt.figure(figsize=(6, 4))
sns.lineplot(data=temperature_distance_data, x='temperature', y='mean_distances', hue='model', marker='o', palette=selected_colors)
plt.title('Effect of Temperature on MAE for Each Model')
plt.xlabel('Temperature')
plt.ylabel('MAE')
plt.legend(title='Model') #, bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.savefig('figures/temperature_distance.pdf')

plt.show()
